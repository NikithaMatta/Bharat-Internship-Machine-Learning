# %%
import pandas as pd

# %%
df= pd.read_csv("Movie.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#      director_name     actor_1_name    actor_2_name    actor_3_name  \
# 0    John Lasseter        Tom Hanks       Tim Allen     Don Rickles
# 1     Joe Johnston   Robin Williams   Jonathan Hyde   Kirsten Dunst
# 2    Howard Deutch   Walter Matthau     Jack Lemmon     Ann-Margret
# 3  Forest Whitaker  Whitney Houston  Angela Bassett  Loretta Devine
# 4    Charles Shyer     Steve Martin    Diane Keaton    Martin Short
#
#                      genres                  movie_title  \
# 0   Animation Comedy Family                    toy story
# 1  Adventure Fantasy Family                      jumanji
# 2            Romance Comedy             grumpier old men
# 3      Comedy Drama Romance            waiting to exhale
# 4                    Comedy  father of the bride part ii
#
#                                                 comb
# 0  Tom Hanks Tim Allen Don Rickles John Lasseter ...
# 1  Robin Williams Jonathan Hyde Kirsten Dunst Joe...
# ...

# %%
df.head(10)
# Out:
#      director_name            actor_1_name    actor_2_name  \
# 0    John Lasseter               Tom Hanks       Tim Allen
# 1     Joe Johnston          Robin Williams   Jonathan Hyde
# 2    Howard Deutch          Walter Matthau     Jack Lemmon
# 3  Forest Whitaker         Whitney Houston  Angela Bassett
# 4    Charles Shyer            Steve Martin    Diane Keaton
# 5     Peter Hewitt  Jonathan Taylor Thomas     Brad Renfro
# 6      Peter Hyams   Jean-Claude Van Damme   Powers Boothe
# 7  Martin Campbell          Pierce Brosnan       Sean Bean
# 8       Rob Reiner         Michael Douglas  Annette Bening
# 9       Mel Brooks          Leslie Nielsen      Mel Brooks
#
#          actor_3_name                         genres  \
# 0         Don Rickles        Animation Comedy Family
# 1       Kirsten Dunst       Adventure Fantasy Family
# 2         Ann-Margret                 Romance Comedy
# 3      Loretta Devine           Comedy Drama Romance
# ...

# %%
df.tail()
# Out:
#         director_name    actor_1_name  actor_2_name     actor_3_name  \
# 36336        Ben Rock      Monty Bane   Lucy Butler    David Grammer
# 36337   Aaron Osborne      Lisa Boyle     Kena Land    Zaneta Polard
# 36338      John Irvin  Patrick Bergin   Uma Thurman  David Morrissey
# 36339        Lav Diaz    Angel Aquino   Perry Dizon    Hazel Orencio
# 36340  Mark L. Lester   Erika Eleniak  Adam Baldwin    Julie du Page
#
#                       genres          movie_title  \
# 36336                 Horror  the burkittsville 7
# 36337                 Sci-Fi      caged heat 3000
# 36338   Drama Action Romance           robin hood
# 36339                  Drama  century of birthing
# 36340  Action Drama Thriller             betrayal
#
#                                                     comb
# 36336  Monty Bane Lucy Butler David Grammer Ben Rock ...
# 36337  Lisa Boyle Kena Land Zaneta Polard Aaron Osbor...
# 36338  Patrick Bergin Uma Thurman David Morrissey Joh...
# ...

# %%
df.tail(10)
# Out:
#                       director_name     actor_1_name    actor_2_name  \
# 36331  Saul Blinkoff Elliot M. Bour    Jimmy Bennett    Peter Cullen
# 36332                  Ravi Udyawar   Sridevi Kapoor       Sajal Ali
# 36333                Shanra J. Kehl     Markie Adams  Roberto Aguire
# 36334                Jean Yarbrough     Rondo Hatton   Robert Lowery
# 36335                      Ben Rock  Tony Abatemarco    Andre Brooks
# 36336                      Ben Rock       Monty Bane     Lucy Butler
# 36337                 Aaron Osborne       Lisa Boyle       Kena Land
# 36338                    John Irvin   Patrick Bergin     Uma Thurman
# 36339                      Lav Diaz     Angel Aquino     Perry Dizon
# 36340                Mark L. Lester    Erika Eleniak    Adam Baldwin
#
#              actor_3_name                   genres  \
# 36331        Jim Cummings         Animation Family
# 36332      Akshaye Khanna     Crime Drama Thriller
# ...

# %%
df.shape
# Out:
# (36341, 7)

# %%
list(df.columns)
# Out:
# ['director_name',
#  'actor_1_name',
#  'actor_2_name',
#  'actor_3_name',
#  'genres',
#  'movie_title',
#  'comb']

# %%
df.head(5).transpose()
# Out:
#                                                                0  \
# director_name                                      John Lasseter
# actor_1_name                                           Tom Hanks
# actor_2_name                                           Tim Allen
# actor_3_name                                         Don Rickles
# genres                                   Animation Comedy Family
# movie_title                                            toy story
# comb           Tom Hanks Tim Allen Don Rickles John Lasseter ...
#
#                                                                1  \
# director_name                                       Joe Johnston
# actor_1_name                                      Robin Williams
# actor_2_name                                       Jonathan Hyde
# actor_3_name                                       Kirsten Dunst
# genres                                  Adventure Fantasy Family
# ...

# %%
df[['movie_title', 'genres']][:10]
# Out:
#                    movie_title                         genres
# 0                    toy story        Animation Comedy Family
# 1                      jumanji       Adventure Fantasy Family
# 2             grumpier old men                 Romance Comedy
# 3            waiting to exhale           Comedy Drama Romance
# 4  father of the bride part ii                         Comedy
# 5                 tom and huck  Action Adventure Drama Family
# 6                 sudden death      Action Adventure Thriller
# 7                    goldeneye      Adventure Action Thriller
# 8       the american president           Comedy Drama Romance
# 9  dracula: dead and loving it                  Comedy Horror

# %%
df.iloc[10:17]
# Out:
#                                         director_name     actor_1_name  \
# 10                                        Simon Wells      Kevin Bacon
# 11                                       Oliver Stone  Anthony Hopkins
# 12                                       Renny Harlin      Geena Davis
# 13                                    Martin Scorsese   Robert De Niro
# 14  Allison Anders Alexandre Rockwell Robert Rodri...         Tim Roth
# 15                                     Steve Oedekerk       Jim Carrey
# 16                                       Joseph Ruben    Wesley Snipes
#
#         actor_2_name    actor_3_name                      genres  \
# 10       Bob Hoskins   Bridget Fonda  Family Animation Adventure
# 11        Joan Allen   Powers Boothe               History Drama
# 12    Matthew Modine  Frank Langella            Action Adventure
# 13      Sharon Stone       Joe Pesci                 Drama Crime
# 14  Antonio Banderas  Jennifer Beals                Crime Comedy
# ...

# %%
df.iloc[4:9,1:4]
# Out:
#              actor_1_name    actor_2_name        actor_3_name
# 4            Steve Martin    Diane Keaton        Martin Short
# 5  Jonathan Taylor Thomas     Brad Renfro  Rachael Leigh Cook
# 6   Jean-Claude Van Damme   Powers Boothe     Dorian Harewood
# 7          Pierce Brosnan       Sean Bean   Izabella Scorupco
# 8         Michael Douglas  Annette Bening      Michael J. Fox

# %%
df.director_name.value_counts()
# Out:
# John Ford                              58
# Michael Curtiz                         51
# Woody Allen                            44
# Henry Hathaway                         39
# Charlie Chaplin                        38
#                                        ..
# Marion Cajori Amei Wallach              1
# Katerina Kitidi Aris Chatzistefanou     1
# Joris Ivens                             1
# Davy Rothbart Andrew Cohn               1
# Aaron Osborne                           1
# Name: director_name, Length: 15710, dtype: int64

# %%
df.director_name.value_counts(normalize=True)*100
# Out:
# John Ford                              0.159599
# Michael Curtiz                         0.140337
# Woody Allen                            0.121075
# Henry Hathaway                         0.107317
# Charlie Chaplin                        0.104565
#                                          ...
# Marion Cajori Amei Wallach             0.002752
# Katerina Kitidi Aris Chatzistefanou    0.002752
# Joris Ivens                            0.002752
# Davy Rothbart Andrew Cohn              0.002752
# Aaron Osborne                          0.002752
# Name: director_name, Length: 15710, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df= df.head(100)

# %%
plt.scatter(df['director_name'], df['genres'])

# %%
plt.bar(df['genres'],df['actor_nam'])
